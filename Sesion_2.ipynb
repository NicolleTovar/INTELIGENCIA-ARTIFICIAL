# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolleTovar/INTELIGENCIA-ARTIFICIAL/blob/main/Sesion_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![JUEGO}.PNG](data:image/png;base64,...)
